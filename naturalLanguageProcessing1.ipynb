# %%
# Source : 
# https://colab.research.google.com/drive/1vt4u8Hp-iQIRSFc633Outvl7t3R34-iJ?usp=sharing#scrollTo=8CbkQnvBVXPv

# %%
text_file = open("dataSource/nlp1source.txt")
text = text_file.read()

# print data type of the file 
print(type(text))
print("\n")
# print the text 
print(text)
print("\n")
# length of the text : 
print("Length : ", len(text))
# Out:
# <class 'str'>
#
#
# Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them. So when they were old enough, she sent them out into the world to seek their fortunes.
#
# The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he built his house out of sticks. Then, they sang and danced and played together the rest of the day.
#
# The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.
#
#
# Length :  675

# %%
import nltk 
from nltk import sent_tokenize 
from nltk import word_tokenize

nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package names to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package shakespeare to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package treebank to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package omw to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet31 to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package snowball_data to C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\zakiy
# [nltk_data]    |     farhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\zakiy
# [nltk_data]     farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# Tokenize the text by sentences 
sentences = sent_tokenize(text)
print(len(sentences))

# print the sentences
sentences
# Out:
# 9
# ['Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them.',
#  'So when they were old enough, she sent them out into the world to seek their fortunes.',
#  'The first little pig was very lazy.',
#  "He didn't want to work at all and he built his house out of straw.",
#  'The second little pig worked a little bit harder but he was somewhat lazy too and he built his house out of sticks.',
#  'Then, they sang and danced and played together the rest of the day.',
#  'The third little pig worked hard all day and built his house with bricks.',
#  'It was a sturdy house complete with a fine fireplace and chimney.',
#  'It looked like it could withstand the strongest winds.']
